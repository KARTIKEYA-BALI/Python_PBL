# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt   
import nlpaug.augmenter.word as naw
import nltk

# %%
"""LOADED THE DATASET"""
# data=pd.read_csv(r"C:\Users\balih\Desktop\AI ML lab work\Python_PBL\Datasets\PBL_DATA.csv")

# %%
"""TOKENIZING OUR DATA"""
from nltk import word_tokenize  as wdt
# data['token'] = data['text'].apply(wdt)

# %%
# data['token']
# Out:
# 0        [gary, production, from, the, high, island, la...
# 1                   [calpine, daily, gas, nomination, doc]
# 2        [fyi, see, note, below, already, done, stella,...
# 3        [fyi, forwarded, by, lauri, allen, hou, ect, o...
# 4        [jackie, since, the, inlet, to, river, plant, ...
#                                ...
# 39437    [can, succeed, of, music, gift, vouchers, ever...
# 39438    [welcome, to, ukmobiledate, this, msg, is, fre...
# 39439    [welcome, to, ukmobiledate, this, msg, exist, ...
# 39440    [welcome, to, ukmobiledate, this, msg, be, fre...
# 39441    [convey, the, official, england, poly, rington...
# Name: token, Length: 39442, dtype: object

# %%
"""CHECKING FOR NULL AND DUPLICATES TOKENS"""
# print(f"the null are:{data['token'].isnull().sum()}")
# print(f"the duplicates are:{data['token'].duplicated().sum()}")
# Out:
# the null are:0
# the duplicates are:163

# %%
"""DROPPING THE DUPLICATE TOKENS"""
# data.drop_duplicates(subset=['token'],inplace=True)

# %%
"""REMOVING STOPWORDS FROM THE DATA"""

from nltk.corpus import stopwords 
stp_wrds=set(stopwords.words('english'))
def stopword_hattao(l:list):
    stop_nikal=[]
    for words in l :
        if words not in stp_wrds:
            stop_nikal.append(words)
    return stop_nikal

# data['token']=data['token'].apply(stopword_hattao)
# data['token']
# Out:
# 0        [gary, production, high, island, larger, block...
# 1                   [calpine, daily, gas, nomination, doc]
# 2        [fyi, see, note, already, done, stella, forwar...
# 3        [fyi, forwarded, lauri, allen, hou, ect, pm, k...
# 4        [jackie, since, inlet, river, plant, shut, las...
#                                ...
# 39437    [succeed, music, gift, vouchers, every, week, ...
# 39438    [welcome, ukmobiledate, msg, free, giving, fre...
# 39439    [welcome, ukmobiledate, msg, exist, free, yiel...
# 39440    [welcome, ukmobiledate, msg, free, yield, free...
# 39441    [convey, official, england, poly, ringtone, co...
# Name: token, Length: 39279, dtype: object

# %%
"""STEMMING THE TOKENS IN OUR DATASET"""
from nltk.stem import PorterStemmer
stemmer=PorterStemmer()
def stemming_karo(l):
    for i in range(len(l)):
        l[i]=stemmer.stem(l[i])
    return l

# data['token']=data['token'].apply(stemming_karo)

# %%
"""CHECKING FOR DUPLICATES IN OUR TOKENS"""
print(f"the duplicates are:{data['token'].duplicated().sum()}")
# Out:
# the duplicates are:399

# %%
"""DROPING THE DUPLICATES FROM OUR DATASET"""
# data.drop_duplicates(subset=['token'],inplace=True)
# Out:
#       label                                               text  \
# 0       ham  gary production from the high island larger bl...
# 1       ham                   calpine daily gas nomination doc
# 2       ham  fyi see note below already done stella forward...
# 3       ham  fyi forwarded by lauri allen hou ect on pm kim...
# 4       ham  jackie since the inlet to river plant is shut ...
# ...     ...                                                ...
# 39437  spam   can succeed of music gift vouchers every week...
# 39438  spam  welcome to ukmobiledate this msg is free givin...
# 39439  spam  welcome to ukmobiledate this msg exist free yi...
# 39440  spam  welcome to ukmobiledate this msg be free yield...
# 39441  spam  convey the official england poly ringtone or c...
#
#                                                    token
# 0      [gari, product, high, island, larger, block, c...
# 1                        [calpin, daili, ga, nomin, doc]
# 2      [fyi, see, note, alreadi, done, stella, forwar...
# 3      [fyi, forward, lauri, allen, hou, ect, pm, kim...
# 4      [jacki, sinc, inlet, river, plant, shut, last,...
# ...                                                  ...
# 39437  [succeed, music, gift, voucher, everi, week, i...
# 39438  [welcom, ukmobiled, msg, free, give, free, cal...
# 39439  [welcom, ukmobiled, msg, exist, free, yield, f...
# 39440  [welcom, ukmobiled, msg, free, yield, free, ca...
# 39441  [convey, offici, england, poli, rington, colou...
#
# [38880 rows x 3 columns]

# %%
"""SORTING OUR TOKEN LIST TO SEE WHETHER WE HAVE MORE DUPLICATES OR NOT"""

data['token']=data['token'].apply(sorted)

# %%
"""CHECKING FOR THE SAME DATA"""
print(f"the number of duplicates are:{data['token'].duplicated().sum()}")
data.drop_duplicates(subset=['token'],inplace=True)
# Out:
# the number of duplicates are:43

# %%
"""CREATING A CSV FILE TO PUT OUR DATA"""
data.to_csv(r"C:\Users\balih\Desktop\AI ML lab work\Python_PBL\Datasets\TOKENIZED_PBL_DATA.csv",index=False)

# %%
data=pd.read_csv(r"C:\Users\balih\Desktop\AI ML lab work\Python_PBL\Datasets\TOKENIZED_PBL_DATA.csv")
sns.histplot(data['label'],color='pink')
plt.title("FREQUENCY COMPARISON")
plt.xlabel("LABEL")
plt.ylabel("FREQUENCY")
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
spam=data.loc[data['label']=='spam'].count().tolist()[0]
ham=data.loc[data['label']=='ham'].count().tolist()[0]
print(f"the number of spam are:{spam}\nthe number of ham are:{ham}")
# Out:
# the number of spam are:8884
# the number of ham are:29953

# %%
"""AS WE HAVE MORE HAM DATA HENCE WE HAVE TO DROP THIS DATA AND MAKE IT EVEN"""

# %%
"""DROPPING THE EXTRA HAM LABEL DATA"""

# ham_indices = data[data['label'] == 'ham'].index.unique()

# indices_to_drop=np.random.choice(ham_indices,21000,replace=False)
# data.drop(indices_to_drop,inplace=True)

# %%
"""AFTER DROPPING THE DATA"""
data
# Out:
#       label                                               text  \
# 2       ham  fyi see note below already done stella forward...
# 3       ham  fyi forwarded by lauri allen hou ect on pm kim...
# 4       ham  jackie since the inlet to river plant is shut ...
# 6       ham  fyi forwarded by gary payne hou ect on pm from...
# 16      ham  my latest understanding is the buyback will be...
# ...     ...                                                ...
# 38832  spam   can succeed of music gift vouchers every week...
# 38833  spam  welcome to ukmobiledate this msg is free givin...
# 38834  spam  welcome to ukmobiledate this msg exist free yi...
# 38835  spam  welcome to ukmobiledate this msg be free yield...
# 38836  spam  convey the official england poly ringtone or c...
#
#                                                    token
# 2      ['account', 'alreadi', 'alreadi', 'arrang', 'c...
# 3      ['allen', 'allen', 'allen', 'alloc', 'alloc', ...
# 4      ['activ', 'advic', 'also', 'buy', 'day', 'deal...
# 6      ['agre', 'antoin', 'bernic', 'bussel', 'cal', ...
# 16     ['begin', 'buyback', 'buyback', 'buyback', 'bu...
# ...                                                  ...
# 38832  ['age', 'draw', 'everi', 'gift', 'initi', 'mus...
# 38833  ['bill', 'call', 'cancel', 'daili', 'free', 'f...
# 38834  ['bill', 'call', 'daili', 'exist', 'free', 'fr...
# 38835  ['bill', 'call', 'cancel', 'daili', 'free', 'f...
# 38836  ['colour', 'convey', 'england', 'flag', 'flag'...
#
# [17837 rows x 3 columns]

# %%
"""NEW SPAM AND HAM SPLIT"""

spam=data.loc[data['label']=='spam'].count().tolist()[0]
ham=data.loc[data['label']=='ham'].count().tolist()[0]
print(f"the number of spam are:{spam}\nthe number of ham are:{ham}")
# Out:
# the number of spam are:8884
# the number of ham are:8953

# %%
"""HISTOGRAM FOR VISUALIZATION"""
sns.histplot(data['label'],color='pink')
plt.title("FREQUENCY COMPARISON")
plt.xlabel("LABEL")
plt.ylabel("FREQUENCY")
# Out:
# Text(0, 0.5, 'FREQUENCY')

# %%
"""REPLACING THE LABEL HAM AS 0 AND SPAM AS 1"""
# data['label']=data['label'].replace({"spam":1,"ham":0})

# %%
"""PUSHING THE DATA """
# data.to_csv(r"C:\Users\balih\Desktop\AI ML lab work\Python_PBL\Datasets\TOKENIZED_PBL_DATA.csv",index=False)

# %%
"""NEW DATA"""
# data=pd.read_csv(r"C:\Users\balih\Desktop\AI ML lab work\Python_PBL\Datasets\TOKENIZED_PBL_DATA.csv")
# data
# Out:
#        label                                               text  \
# 0          0  fyi see note below already done stella forward...
# 1          0  fyi forwarded by lauri allen hou ect on pm kim...
# 2          0  jackie since the inlet to river plant is shut ...
# 3          0  fyi forwarded by gary payne hou ect on pm from...
# 4          0  my latest understanding is the buyback will be...
# ...      ...                                                ...
# 17832      1   can succeed of music gift vouchers every week...
# 17833      1  welcome to ukmobiledate this msg is free givin...
# 17834      1  welcome to ukmobiledate this msg exist free yi...
# 17835      1  welcome to ukmobiledate this msg be free yield...
# 17836      1  convey the official england poly ringtone or c...
#
#                                                    token
# 0      ['account', 'alreadi', 'alreadi', 'arrang', 'c...
# 1      ['allen', 'allen', 'allen', 'alloc', 'alloc', ...
# 2      ['activ', 'advic', 'also', 'buy', 'day', 'deal...
# 3      ['agre', 'antoin', 'bernic', 'bussel', 'cal', ...
# 4      ['begin', 'buyback', 'buyback', 'buyback', 'bu...
# ...                                                  ...
# 17832  ['age', 'draw', 'everi', 'gift', 'initi', 'mus...
# 17833  ['bill', 'call', 'cancel', 'daili', 'free', 'f...
# 17834  ['bill', 'call', 'daili', 'exist', 'free', 'fr...
# 17835  ['bill', 'call', 'cancel', 'daili', 'free', 'f...
# 17836  ['colour', 'convey', 'england', 'flag', 'flag'...
#
# [17837 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# data=pd.read_csv(r"C:\Users\balih\Desktop\AI ML lab work\Python_PBL\Datasets\TOKENIZED_PBL_DATA.csv")

# %%
"""TRYING TO CHANGE OUR TOKEN INTO LISTS"""

data['token'].tolist()
# Out:
# ["['account', 'alreadi', 'alreadi', 'arrang', 'camp', 'camp', 'camp', 'camp', 'camp', 'care', 'cc', 'cc', 'cc', 'creat', 'daren', 'daren', 'deal', 'deal', 'done', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'energi', 'expir', 'farmer', 'forward', 'forward', 'fyi', 'hc', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'howard', 'howard', 'howard', 'howard', 'howard', 'issu', 'issu', 'issu', 'meter', 'morri', 'morri', 'morri', 'neuweil', 'note', 'pm', 'purchas', 'resolv', 'schumack', 'schumack', 'schumack', 'see', 'sherlyn', 'sherlyn', 'sherlyn', 'stacey', 'stacey', 'stella', 'stella', 'stella', 'stella', 'stella', 'stella', 'subject', 'subject', 'subject', 'taken', 'thank', 'track', 'unoc', 'volum', 'work', 'yesterday']",
#  "['allen', 'allen', 'allen', 'alloc', 'alloc', 'alloc', 'alloc', 'anita', 'anita', 'camp', 'cc', 'cc', 'close', 'contract', 'contract', 'contract', 'contract', 'daren', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'forward', 'forward', 'fyi', 'ga', 'get', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'howard', 'kim', 'kimberli', 'kimberli', 'kimberli', 'lauri', 'lauri', 'lauri', 'lauri', 'luong', 'make', 'mari', 'mari', 'meter', 'meter', 'mm', 'move', 'nomin', 'nov', 'nov', 'novemb', 'novemb', 'novemb', 'pleas', 'pm', 'pm', 'pm', 'pm', 'point', 'prior', 'put', 'reliant', 'reliant', 'reliant', 'show', 'smith', 'smith', 'stranga', 'subject', 'subject', 'sure', 'thank', 'therefor', 'vaughn', 'vaughn', 'vaughn', 'volum', 'volum', 'volum']",
#  "['activ', 'advic', 'also', 'buy', 'day', 'deal', 'divert', 'flow', 'ga', 'ga', 'ga', 'ga', 'hpl', 'inlet', 'jacki', 'last', 'manag', 'mcmullen', 'meter', 'meter', 'meter', 'meter', 'need', 'path', 'payment', 'plant', 'pleas', 'pop', 'possibl', 'residu', 'resolv', 'river', 'schedul', 'see', 'see', 'send', 'settlement', 'shut', 'sinc', 'soon', 'still', 'swift', 'swift', 'teco', 'teco', 'tejon', 'tejon', 'thank', 'vastar', 'vastar', 'vintag', 'vintag']",
#  "['agre', 'antoin', 'bernic', 'bussel', 'cal', 'cc', 'cernosek', 'chang', 'chang', 'chang', 'chang', 'chang', 'cinergi', 'clem', 'counterparti', 'cp', 'dave', 'david', 'decemb', 'dian', 'dnb', 'dun', 'dunn', 'dynam', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'eiben', 'energi', 'energi', 'forward', 'fyi', 'ga', 'gari', 'gari', 'gilbert', 'gosnel', 'group', 'heal', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'id', 'inc', 'inc', 'inc', 'jason', 'jersey', 'kathryn', 'kevin', 'llc', 'make', 'make', 'manag', 'mari', 'market', 'michael', 'moor', 'niestrath', 'nommensen', 'notifi', 'number', 'number', 'number', 'number', 'otherwis', 'payn', 'payn', 'philadelphia', 'pierr', 'pinion', 'pleas', 'pm', 'pm', 'problem', 'renni', 'resourc', 'resourc', 'richard', 'rodriguez', 'rohan', 'romeo', 'samuel', 'schedul', 'schott', 'scotti', 'south', 'souza', 'subject', 'thank', 'tommi', 'transalta', 'us', 'wednesday', 'work', 'yanowski']",
#  "['begin', 'buyback', 'buyback', 'buyback', 'buyback', 'camp', 'camp', 'cc', 'cc', 'citgo', 'citgo', 'could', 'current', 'day', 'deal', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'effect', 'gari', 'gari', 'hanson', 'hc', 'hou', 'hou', 'hou', 'hou', 'hou', 'howard', 'howard', 'inform', 'ken', 'kenneth', 'kristen', 'lamphier', 'latest', 'lyondel', 'lyondel', 'mail', 'new', 'notifi', 'place', 'pleas', 'pm', 'possibl', 'provis', 'review', 'seaman', 'statu', 'subject', 'tina', 'understand', 'valadez', 'via']",
#  "['absenc', 'actual', 'back', 'carri', 'cell', 'cellular', 'christin', 'contact', 'countri', 'dec', 'ext', 'ext', 'follow', 'fyi', 'great', 'holiday', 'jan', 'jan', 'macphail', 'nd', 'offic', 'offic', 'oncal', 'oncal', 'page', 'pager', 'person', 'person', 'personel', 'pham', 'phone', 'pleas', 'pop', 'pop', 'pop', 'problem', 'question', 'romeo', 'season', 'shawn', 'souza', 'st', 'start', 'support', 'support', 'support', 'th']",
#  "['attach', 'attach', 'call', 'carlo', 'carlo', 'carlo', 'cc', 'chang', 'chang', 'christma', 'complet', 'confid', 'costilla', 'custom', 'daren', 'daren', 'ect', 'ect', 'ect', 'ect', 'ect', 'estim', 'estim', 'estim', 'estim', 'except', 'fax', 'feel', 'file', 'file', 'file', 'final', 'forward', 'good', 'grave', 'hope', 'hou', 'hou', 'hou', 'howev', 'januari', 'januari', 'know', 'last', 'let', 'made', 'melissa', 'merri', 'monday', 'monday', 'much', 'nom', 'nom', 'nomin', 'noon', 'number', 'pleas', 'pleas', 'pleas', 'pm', 'pretti', 'pretti', 'product', 'product', 'provid', 'question', 'receiv', 'receiv', 'review', 'said', 'sc', 'see', 'send', 'smith', 'smith', 'subject', 'superior', 'susan', 'susan', 'susan', 'taylor', 'thank', 'thank', 'therefor', 'trader', 'updat', 'vanc', 'vlt', 'walter', 'week', 'would']",
#  "['adjust', 'anyth', 'back', 'camp', 'cc', 'chang', 'control', 'correct', 'daren', 'ect', 'ect', 'ect', 'ect', 'ect', 'els', 'flow', 'forgot', 'forward', 'ga', 'given', 'hl', 'hl', 'hou', 'hou', 'hou', 'howard', 'includ', 'jac', 'janet', 'janet', 'jill', 'kimberli', 'kimberli', 'know', 'let', 'meter', 'monitor', 'mtd', 'necessari', 'need', 'nom', 'pm', 'pm', 'problem', 'san', 'scada', 'scada', 'sitara', 'sorri', 'subject', 'th', 'th', 'th', 'th', 'thank', 'told', 'updat', 'vacat', 'vaughn', 'vaughn', 'verbal', 'walli']",
#  "['alreadi', 'also', 'ami', 'ami', 'ami', 'anoth', 'approx', 'basket', 'belong', 'call', 'cc', 'ce', 'channel', 'check', 'chokshi', 'chokshi', 'choos', 'com', 'contract', 'corp', 'corp', 'david', 'david', 'deal', 'desk', 'directli', 'dscottl', 'enron', 'enron', 'enron', 'entex', 'entex', 'entex', 'entex', 'except', 'firm', 'forward', 'ga', 'ga', 'ga', 'got', 'got', 'group', 'guess', 'hey', 'highest', 'hpl', 'includ', 'index', 'indic', 'inform', 'inform', 'inform', 'invoic', 'joe', 'keep', 'km', 'km', 'km', 'know', 'know', 'let', 'long', 'mi', 'midcon', 'monthli', 'move', 'need', 'pay', 'pay', 'pipe', 'place', 'point', 'probabl', 'provid', 'receiv', 'regard', 'rememb', 'respons', 'respons', 'risk', 'sell', 'sourc', 'structur', 'stx', 'subject', 'take', 'teja', 'tetco', 'tomcat', 'tomcat', 'tomcat', 'usual', 'volum', 'would', 'written']",
#  "['abbrevi', 'approv', 'channel', 'channel', 'code', 'comment', 'compani', 'confirm', 'content', 'darren', 'deliveri', 'descript', 'descript', 'draft', 'elsa', 'houston', 'houston', 'houston', 'hpl', 'hsc', 'languag', 'line', 'offer', 'pipe', 'pleas', 'point', 'pool', 'pursuant', 'recent', 'regard', 'ship', 'ship', 'sort', 'suggest', 'tbd', 'transact', 'via', 'zone']",
#  "['ami', 'big', 'conro', 'day', 'day', 'huntsvil', 'ticket', 'woodland']",
#  "['ami', 'ami', 'ami', 'back', 'cc', 'cc', 'chokshi', 'chokshi', 'chokshi', 'comita', 'connor', 'corp', 'corp', 'counti', 'counti', 'counti', 'counti', 'counti', 'counti', 'descript', 'descript', 'direct', 'direct', 'ect', 'ect', 'ect', 'elli', 'elli', 'energi', 'energi', 'energi', 'enron', 'enron', 'enron', 'enron', 'facil', 'facil', 'fay', 'fay', 'fay', 'flow', 'flow', 'follow', 'forward', 'fyi', 'garza', 'gemc', 'gemc', 'go', 'gpo', 'greta', 'greta', 'gulf', 'gulf', 'gulf', 'hall', 'hall', 'hayn', 'hou', 'jen', 'jen', 'jen', 'mcfaddin', 'meter', 'meter', 'meter', 'meter', 'meter', 'meter', 'meter', 'midcon', 'midcon', 'midcon', 'midcon', 'notif', 'onlin', 'pdc', 'pdc', 'plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'pm', 'pm', 'pool', 'pool', 'pool', 'pool', 'pool', 'pool', 'pool', 'ranch', 'receipt', 'receipt', 'receipt', 'refugio', 'request', 'roc', 'send', 'sinc', 'south', 'staci', 'subject', 'subject', 'submit', 'teja', 'texa', 'therefor', 'tom', 'trevino', 'tx', 'tx', 'tx', 'type', 'type', 'type', 'type', 'zapata', 'zapata']",
#  "['accord', 'check', 'check', 'cpr', 'daren', 'deal', 'deal', 'fed', 'flow', 'flow', 'flow', 'ga', 'howev', 'hpl', 'indic', 'may', 'measur', 'measur', 'mip', 'mmbtu', 'month', 'noth', 'oss', 'oss', 'oss', 'oss', 'rate', 'receiv', 'revis', 'seem', 'statement', 'stella', 'strang', 'support', 'thank', 'whole', 'year']",
#  "['back', 'bammel', 'chang', 'charlott', 'clear', 'daren', 'day', 'day', 'error', 'noon', 'ps', 'sent', 'thank', 'tomorrow', 'transco', 'volum', 'volum']",
#  "['attach', 'janet', 'number', 'recent']",
#  "['alway', 'ami', 'conro', 'deal', 'entex', 'even', 'everi', 'everi', 'hc', 'make', 'month', 'month', 'need', 'nom', 'nom', 'nov', 'send', 'set', 'sitara', 'sure', 'volum']",
#  "['agre', 'agre', 'aime', 'batch', 'call', 'charlott', 'ga', 'give', 'hold', 'hold', 'januari', 'januari', 'larri', 'morn', 'nomin', 'outag', 'point', 'question', 'regard', 'rest', 'spoke', 'throughout', 'us', 'zamit']",
#  "['agre', 'agre', 'aime', 'aime', 'allen', 'back', 'batch', 'call', 'cc', 'charlott', 'charlott', 'clyne', 'corp', 'daren', 'duke', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'edward', 'effect', 'elsa', 'enron', 'enron', 'farmer', 'forward', 'ga', 'ga', 'gari', 'gari', 'gari', 'give', 'gottlob', 'hank', 'hank', 'hawkin', 'hold', 'hold', 'hold', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'januari', 'januari', 'koch', 'lannou', 'larri', 'lauri', 'morn', 'need', 'nomin', 'outag', 'outag', 'pat', 'point', 'question', 'regard', 'rest', 'river', 'schedul', 'spoke', 'subject', 'three', 'throughout', 'throught', 'us', 'villarr', 'zamit']",
#  "['accuraci', 'address', 'address', 'agre', 'alloc', 'also', 'also', 'amend', 'ami', 'appropri', 'assign', 'assign', 'assign', 'assign', 'assign', 'assign', 'assign', 'assign', 'assum', 'back', 'base', 'broker', 'broker', 'busi', 'busi', 'carlo', 'carlo', 'carlo', 'carlo', 'channel', 'cleanup', 'confirm', 'confus', 'confus', 'contract', 'contract', 'contract', 'contract', 'could', 'cover', 'current', 'deal', 'deal', 'deal', 'dec', 'dec', 'dec', 'decemb', 'decemb', 'decemb', 'decis', 'del', 'desk', 'desk', 'dicsuss', 'duti', 'eisenhour', 'electron', 'ena', 'ena', 'ena', 'enough', 'enron', 'everyon', 'except', 'expens', 'expens', 'expens', 'expens', 'field', 'find', 'flow', 'follow', 'forward', 'found', 'fyi', 'ga', 'ga', 'ga', 'ga', 'get', 'get', 'get', 'get', 'handl', 'handl', 'handl', 'handl', 'hank', 'hank', 'hpl', 'hpl', 'hpl', 'hpl', 'hplc', 'hplc', 'hplc', 'industri', 'intrast', 'issu', 'issu', 'issu', 'issu', 'issu', 'issu', 'issu', 'issu', 'jan', 'jan', 'jan', 'jan', 'januari', 'januari', 'januari', 'know', 'know', 'lavaca', 'left', 'left', 'left', 'left', 'left', 'left', 'legal', 'let', 'like', 'list', 'logist', 'long', 'long', 'long', 'look', 'lot', 'lot', 'made', 'manag', 'mandey', 'mari', 'meet', 'meter', 'meter', 'midcon', 'might', 'might', 'month', 'move', 'mtr', 'mtr', 'necessari', 'need', 'need', 'need', 'need', 'need', 'need', 'need', 'need', 'next', 'nom', 'nom', 'nomin', 'nomin', 'nomin', 'nomin', 'none', 'note', 'obviou', 'octob', 'offsystem', 'offsystem', 'offsystem', 'old', 'one', 'one', 'one', 'oper', 'oper', 'paper', 'pat', 'path', 'path', 'path', 'path', 'path', 'path', 'pipe', 'pipe', 'pipe', 'pipelin', 'pipelin', 'pipelin', 'point', 'pop', 'posit', 'possibl', 'present', 'prior', 'proceed', 'quickli', 'quickli', 'rate', 'rate', 'rec', 'recollect', 'recollect', 'rep', 'requir', 'respons', 'respons', 'respons', 'return', 'review', 'said', 'sale', 'sale', 'see', 'seem', 'seem', 'seen', 'septemb', 'servic', 'sever', 'shipper', 'sinc', 'sinc', 'sinc', 'smith', 'someon', 'someon', 'specif', 'split', 'split', 'stacey', 'stand', 'still', 'stop', 'suppli', 'term', 'term', 'texa', 'think', 'think', 'thought', 'thought', 'took', 'transact', 'transact', 'transact', 'transact', 'transport', 'transport', 'transport', 'transport', 'transport', 'transport', 'tri', 'two', 'unassign', 'unassign', 'undevelop', 'unifi', 'unifi', 'unpath', 'unpath', 'unpath', 'unpath', 'unpath', 'unresolv', 'unresolv', 'unsresolv', 'view', 'volum', 'wait', 'want', 'want', 'week', 'went', 'whether', 'wrong', 'zero', 'zone', 'zone']",
#  "['enron', 'enron', 'hpl', 'hpl', 'ic', 'iferc', 'kati', 'ls', 'tap', 'tap', 'teco', 'teco']",
#  "['activ', 'adequ', 'adjust', 'begin', 'best', 'bid', 'chang', 'comfort', 'complet', 'could', 'deal', 'design', 'desk', 'earli', 'earli', 'either', 'either', 'featur', 'featur', 'give', 'go', 'group', 'heather', 'like', 'like', 'limit', 'manag', 'migrat', 'migrat', 'minut', 'new', 'next', 'next', 'next', 'next', 'path', 'perform', 'period', 'pleas', 'prepar', 'prior', 'product', 'product', 'projector', 'quick', 'real', 'receiv', 'roll', 'room', 'schedul', 'schedul', 'schedul', 'schedul', 'schedul', 'scotti', 'secur', 'select', 'sitara', 'sometim', 'take', 'test', 'test', 'thank', 'thru', 'time', 'time', 'train', 'unifi', 'updat', 'us', 'via', 'walkthru', 'week', 'week', 'week', 'week', 'week', 'week', 'work', 'would', 'would', 'would']",
#  "['alloc', 'come', 'correct', 'correctli', 'ga', 'go', 'help', 'identifi', 'jan', 'ken', 'kind', 'know', 'let', 'like', 'like', 'look', 'problem', 'research', 'thing']",
#  "['alreadi', 'appreci', 'appreci', 'class', 'clyne', 'daren', 'effort', 'extrem', 'feedback', 'futur', 'great', 'group', 'group', 'group', 'handout', 'heard', 'logist', 'materi', 'much', 'pat', 'posit', 'put', 'refer', 'rest', 'set', 'sitara', 'taught', 'thank', 'thank', 'time', 'train', 'us', 'valuabl']",
#  "['agenc', 'alloc', 'ami', 'bdpl', 'bdpl', 'blue', 'blue', 'blue', 'brazoria', 'buy', 'contact', 'contract', 'contract', 'counti', 'current', 'da', 'davenport', 'day', 'dehi', 'dehi', 'dolphin', 'dolphin', 'dolphin', 'dow', 'dow', 'enron', 'eventu', 'fee', 'field', 'galveston', 'gd', 'gd', 'given', 'gtsa', 'hsc', 'hsc', 'inlet', 'island', 'janen', 'jean', 'jean', 'ken', 'krink', 'mari', 'mari', 'mei', 'mmbtu', 'nomin', 'oper', 'per', 'pipelin', 'plant', 'plu', 'produc', 'product', 'requir', 'samedan', 'shipp', 'sold', 'spinnak', 'start', 'term', 'transport', 'transport', 'transport', 'tsp', 'volum', 'volum', 'whatev', 'xl', 'xl']",
#  "['ami', 'ami', 'attach', 'benoit', 'cc', 'chang', 'chokshi', 'chokshi', 'com', 'copano', 'corp', 'corp', 'enron', 'enron', 'enron', 'file', 'forward', 'hpl', 'hpl', 'jan', 'jan', 'reliantenergi', 'see', 'subject', 'th', 'troy', 'xl', 'xl']",
#  "['access', 'access', 'advanc', 'appreci', 'assign', 'assign', 'back', 'bridg', 'call', 'chang', 'checkout', 'continu', 'convers', 'convert', 'cpr', 'cst', 'cst', 'cst', 'cst', 'data', 'data', 'date', 'deal', 'environ', 'environ', 'everyon', 'follow', 'forthcom', 'fri', 'fri', 'group', 'happen', 'help', 'hesit', 'hot', 'hotlin', 'howev', 'impact', 'impact', 'includ', 'item', 'kept', 'lack', 'largest', 'like', 'list', 'make', 'make', 'mill', 'notic', 'order', 'parallel', 'parallel', 'parallel', 'parallel', 'parallel', 'period', 'pleas', 'plenti', 'pm', 'pm', 'pm', 'prepar', 'product', 'product', 'product', 'product', 'question', 'releas', 'releas', 'releas', 'releas', 'requir', 'review', 'risk', 'risk', 'schedul', 'scott', 'shorten', 'sitara', 'sitara', 'sitara', 'sitara', 'sitara', 'sitara', 'staff', 'state', 'sun', 'sure', 'thru', 'thru', 'time', 'time', 'train', 'tue', 'unavail', 'unifi', 'upcom', 'updat', 'use', 'user', 'view', 'view', 'want', 'well', 'would']",
#  "['attl', 'comment', 'daren', 'feel', 'htm', 'ken', 'mutual', 'thank']",
#  "['access', 'also', 'app', 'awar', 'becom', 'calgari', 'calgari', 'chang', 'chang', 'clean', 'close', 'close', 'complet', 'could', 'dave', 'demo', 'demo', 'desir', 'error', 'even', 'except', 'feel', 'filter', 'folk', 'folk', 'follow', 'function', 'held', 'includ', 'instal', 'instal', 'insur', 'insur', 'insur', 'item', 'januari', 'januari', 'know', 'last', 'let', 'level', 'like', 'like', 'list', 'logist', 'logist', 'manag', 'may', 'met', 'migrat', 'miss', 'monday', 'monday', 'morn', 'msg', 'need', 'network', 'new', 'night', 'none', 'ok', 'one', 'path', 'paul', 'paul', 'plan', 'pleas', 'pleas', 'print', 'product', 'receiv', 'region', 'relat', 'repres', 'request', 'revis', 'rollout', 'schedul', 'schedul', 'schedul', 'scotti', 'scotti', 'secur', 'select', 'server', 'server', 'sinc', 'stage', 'termin', 'termin', 'texa', 'texa', 'thank', 'thru', 'tibco', 'tibco', 'today', 'tuesday', 'tuesday', 'us', 'use', 'walk', 'wednesday', 'well', 'work', 'would']",
#  "['day', 'day', 'discrep', 'good', 'hpl', 'know', 'let', 'number', 'pg', 'pg', 'pleas', 'thank', 'thu']",
#  "['advic', 'aggreg', 'also', 'anita', 'camp', 'cc', 'charg', 'day', 'day', 'decemb', 'ect', 'ect', 'ect', 'ect', 'ect', 'follow', 'forward', 'handl', 'hl', 'hl', 'hou', 'hou', 'hou', 'howard', 'kimberli', 'kimberli', 'look', 'luong', 'meter', 'meter', 'month', 'notic', 'parti', 'penalti', 'pleas', 'pm', 'rd', 'reliant', 'reliant', 'sale', 'seen', 'short', 'short', 'strang', 'subject', 'th', 'th', 'th', 'th', 'th', 'th', 'th', 'th', 'thank', 'transport', 'transport', 'vaughn', 'vaughn', 'want']",
#  "['accordingli', 'advic', 'aggreg', 'alloc', 'alloc', 'allow', 'also', 'anita', 'anita', 'appli', 'back', 'bill', 'camp', 'camp', 'cc', 'cc', 'charg', 'clyne', 'contract', 'contract', 'corp', 'daren', 'day', 'day', 'day', 'decemb', 'decis', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ena', 'enron', 'enron', 'farmer', 'follow', 'follow', 'forward', 'handl', 'hl', 'hl', 'hl', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'howard', 'howard', 'howev', 'janet', 'janet', 'kimberli', 'kimberli', 'kimberli', 'languag', 'languag', 'look', 'luong', 'luong', 'makeup', 'meter', 'meter', 'month', 'need', 'nomin', 'notic', 'part', 'parti', 'pat', 'penalti', 'per', 'pipelin', 'pipelin', 'pleas', 'pm', 'pm', 'purchas', 'rd', 'reliant', 'reliant', 'rememb', 'rememb', 'sale', 'seen', 'shipper', 'short', 'short', 'shortag', 'strang', 'subject', 'subject', 'th', 'th', 'th', 'th', 'th', 'th', 'th', 'th', 'th', 'th', 'th', 'thank', 'thank', 'toler', 'total', 'toward', 'transport', 'transport', 'vaughn', 'vaughn', 'vaughn', 'volum', 'volum', 'walli', 'want']",
#  "['advis', 'broker', 'contract', 'daren', 'ena', 'except', 'hpl', 'meter', 'meter', 'meter', 'month', 'net', 'nom', 'past', 'pleas', 'report', 'see', 'show', 'thank', 'two', 'vol', 'vol']",
#  "['attach', 'file', 'hplol', 'hplol', 'see', 'xl', 'xl']",
#  "['aforement', 'approxim', 'call', 'came', 'corpor', 'counterparti', 'daili', 'follow', 'ga', 'ga', 'give', 'gu', 'hsc', 'inform', 'koontz', 'kutcha', 'less', 'line', 'meter', 'mmcf', 'morn', 'petroleum', 'pleas', 'pleas', 'price', 'put', 'question', 'reflect', 'rincon', 'sitara', 'thank', 'ticket', 'tom', 'vlt', 'volum', 'well', 'well']",
#  "['addit', 'addit', 'alloc', 'anita', 'anita', 'anita', 'anita', 'anita', 'anita', 'anita', 'anita', 'anita', 'anita', 'anita', 'anita', 'anita', 'anita', 'anita', 'away', 'away', 'back', 'balanc', 'broker', 'broker', 'buy', 'call', 'camp', 'camp', 'camp', 'camp', 'cc', 'cc', 'cc', 'cc', 'cc', 'cc', 'cc', 'cc', 'ccmail', 'chanc', 'chanc', 'check', 'clear', 'clear', 'clear', 'clear', 'clear', 'clear', 'clear', 'clear', 'clear', 'clear', 'convers', 'could', 'current', 'daren', 'daren', 'daren', 'daren', 'date', 'deal', 'deal', 'deal', 'deal', 'deliveri', 'deliveri', 'deliveri', 'deliveri', 'deliveri', 'determin', 'displac', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'except', 'exxon', 'exxon', 'exxon', 'exxon', 'exxon', 'exxon', 'exxon', 'exxon', 'farmer', 'farmer', 'first', 'forward', 'forward', 'forward', 'forward', 'forward', 'forward', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'ga', 'help', 'hope', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'howard', 'howard', 'howard', 'howard', 'hpl', 'info', 'inform', 'inform', 'issu', 'issu', 'issu', 'juli', 'kim', 'kim', 'kimberli', 'kimberli', 'kimberli', 'kimberli', 'kimberli', 'kimberli', 'know', 'know', 'know', 'know', 'know', 'lake', 'lake', 'lake', 'lake', 'lake', 'lake', 'lake', 'lake', 'let', 'let', 'let', 'let', 'let', 'like', 'like', 'list', 'lloyd', 'lloyd', 'look', 'look', 'luong', 'luong', 'luong', 'luong', 'luong', 'luong', 'luong', 'luong', 'luong', 'luong', 'luong', 'luong', 'manag', 'market', 'market', 'market', 'meter', 'meter', 'meter', 'meter', 'meter', 'meter', 'meter', 'meter', 'meter', 'meter', 'meter', 'mkt', 'mmbtu', 'mmbtu', 'mmbtu', 'mmbtu', 'mmbtu', 'mmbtu', 'mmbtu', 'mmbtu', 'mmbtu', 'month', 'morn', 'natur', 'need', 'need', 'need', 'need', 'need', 'need', 'need', 'order', 'order', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'panenergi', 'path', 'pay', 'philip', 'phillip', 'pipelin', 'pleas', 'pleas', 'pleas', 'pleas', 'pm', 'pm', 'pm', 'pm', 'pm', 'pm', 'pm', 'pm', 'pm', 'point', 'point', 'pop', 'pop', 'pop', 'possibl', 'purchas', 'question', 'question', 'question', 'question', 'rebekah', 'rebekah', 'rebekah', 'rebekah', 'rebekah', 'refer', 'regard', 'renomin', 'research', 'resolv', 'revisit', 'revisit', 'robert', 'robert', 'rs', 'rs', 'sale', 'sale', 'sale', 'sale', 'sale', 'sale', 'sale', 'sale', 'sale', 'sale', 'sale', 'schedul', 'schedul', 'seal', 'seal', 'seal', 'seal', 'seal', 'see', 'see', 'see', 'seem', 'sell', 'sell', 'sell', 'show', 'sold', 'sold', 'soon', 'sooner', 'subject', 'subject', 'subject', 'subject', 'subject', 'subject', 'subject', 'subject', 'superior', 'superior', 'take', 'thank', 'thank', 'thank', 'thank', 'thank', 'therefor', 'thing', 'ticket', 'today', 'tomorrow', 'total', 'tranport', 'transact', 'transact', 'transport', 'transport', 'transport', 'vaughn', 'vaughn', 'vaughn', 'vaughn', 'vaughn', 'vaughn', 'verifi', 'volum', 'want', 'whomev', 'whomev', 'work', 'work', 'would', 'would']",
#  "['addit', 'alreadi', 'also', 'also', 'aol', 'attach', 'believ', 'benefit', 'brief', 'candid', 'cc', 'clyne', 'clyne', 'clyne', 'com', 'corp', 'current', 'daren', 'date', 'day', 'doc', 'document', 'document', 'duti', 'employ', 'enron', 'enron', 'farmer', 'flexibl', 'gari', 'good', 'hank', 'inform', 'interview', 'interview', 'januari', 'januari', 'juri', 'keep', 'know', 'know', 'let', 'let', 'like', 'limit', 'mark', 'mark', 'mccoy', 'mccoy', 'met', 'mind', 'mmccoy', 'monday', 'mr', 'mresum', 'need', 'offic', 'offic', 'ok', 'outsid', 'pat', 'pat', 'pleas', 'pleas', 'pm', 'possibl', 'problem', 'question', 'request', 'requir', 'resum', 'samantha', 'schedul', 'sincer', 'sort', 'subject', 'th', 'th', 'thank', 'think', 'would']",
#  "['ami', 'ami', 'attach', 'benoit', 'cc', 'chokshi', 'chokshi', 'citi', 'com', 'corp', 'corp', 'enron', 'enron', 'enron', 'file', 'forward', 'gate', 'hpl', 'hpl', 'jan', 'jan', 'nom', 'reliantenergi', 'see', 'subject', 'troy', 'xl', 'xl']",
#  "['advanc', 'amount', 'anyth', 'chang', 'check', 'check', 'daren', 'date', 'date', 'date', 'date', 'date', 'date', 'date', 'date', 'date', 'date', 'deal', 'deal', 'deal', 'deal', 'deal', 'deliveri', 'estim', 'evergreen', 'evergreen', 'flow', 'flow', 'flow', 'flow', 'flow', 'flow', 'flow', 'flow', 'flow', 'flow', 'follow', 'help', 'help', 'jacki', 'kill', 'kill', 'know', 'knowledg', 'kwa', 'last', 'last', 'last', 'last', 'last', 'last', 'last', 'last', 'last', 'last', 'list', 'meter', 'meter', 'mmbtu', 'month', 'month', 'need', 'new', 'new', 'new', 'note', 'one', 'one', 'one', 'place', 'receipt', 'receipt', 'receipt', 'receipt', 'receipt', 'receipt', 'receipt', 'receipt', 'receipt', 'receipt', 'roll', 'set', 'sitara', 'sitara', 'sitara', 'sitara', 'sitara', 'sitara', 'sitara', 'sitara', 'sitara', 'sitara', 'sitara', 'sitara', 'sitara', 'specifi', 'stop', 'stop', 'stop', 'stop', 'stop', 'stop', 'stop', 'stop', 'stop', 'stop', 'thank', 'vol', 'want', 'wasl', 'without']",
#  "['alloc', 'chang', 'clean', 'column', 'copi', 'distribut', 'given', 'insert', 'manag', 'pleas', 'record', 'send', 'spreadsheet', 'spreadsheet', 'team', 'thank', 'updat', 'want', 'would']",
#  "['accomplish', 'accord', 'accord', 'acknowledg', 'activ', 'actual', 'actual', 'addit', 'adjust', 'agent', 'agre', 'agre', 'agre', 'ami', 'ami', 'amount', 'anoth', 'approxim', 'approxim', 'around', 'arrang', 'avail', 'avail', 'avail', 'availab', 'back', 'balanc', 'base', 'base', 'begin', 'believ', 'bring', 'buy', 'call', 'carthag', 'carthag', 'carthag', 'carthag', 'carthag', 'carthag', 'cass', 'cc', 'ce', 'ce', 'chad', 'chokshi', 'chokshi', 'com', 'com', 'commenc', 'commun', 'continu', 'coordin', 'corp', 'corp', 'corp', 'corp', 'current', 'cut', 'daili', 'daili', 'david', 'day', 'day', 'day', 'day', 'devon', 'devon', 'devon', 'devon', 'devon', 'devon', 'devon', 'devon', 'devon', 'devon', 'devon', 'devon', 'devon', 'devon', 'devon', 'disagre', 'discuss', 'discuss', 'dscottl', 'due', 'duke', 'duke', 'duke', 'duke', 'duke', 'duke', 'duke', 'duke', 'duke', 'dvn', 'effect', 'effect', 'end', 'energi', 'energi', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'estim', 'estim', 'excess', 'exist', 'exist', 'factor', 'fall', 'februari', 'februari', 'ferri', 'forward', 'friday', 'friday', 'ga', 'ga', 'ga', 'ga', 'gregori', 'grew', 'high', 'higher', 'histor', 'hope', 'howev', 'imbal', 'imbal', 'imbal', 'imbal', 'imbal', 'imbal', 'imbal', 'imbal', 'imbal', 'imbal', 'imbal', 'imbal', 'inform', 'issu', 'januari', 'januari', 'key', 'last', 'learn', 'like', 'lst', 'lst', 'make', 'make', 'make', 'make', 'mari', 'met', 'month', 'month', 'month', 'need', 'need', 'need', 'nelson', 'novemb', 'novemb', 'number', 'number', 'octob', 'one', 'oper', 'order', 'overag', 'parti', 'parti', 'pay', 'payback', 'plant', 'plant', 'plant', 'plant', 'plant', 'plant', 'pleas', 'pm', 'pm', 'point', 'posit', 'price', 'product', 'product', 'product', 'prove', 'purchas', 'question', 'receiv', 'recogn', 'reconcil', 'reduc', 'reduc', 'reduc', 'reduc', 'reduct', 'reflect', 'relat', 'request', 'round', 'sale', 'sale', 'sale', 'schockl', 'see', 'seem', 'sell', 'septemb', 'set', 'set', 'shannon', 'shannon', 'side', 'sinc', 'sinc', 'st', 'strive', 'subject', 'tailgat', 'take', 'think', 'think', 'total', 'turn', 'turn', 'verifi', 'verifi', 'volum', 'volum', 'volum', 'volum', 'willi', 'willi', 'willi', 'william', 'work', 'would', 'wrong']",
#  "['abl', 'accomodat', 'account', 'accur', 'add', 'address', 'address', 'address', 'alloc', 'alloc', 'ami', 'ami', 'ami', 'ami', 'answer', 'answer', 'attend', 'attend', 'bass', 'brenda', 'callout', 'camp', 'cc', 'ce', 'ce', 'ce', 'ce', 'chamber', 'chang', 'chokshi', 'clyne', 'com', 'come', 'connevey', 'contact', 'contact', 'contract', 'contract', 'contract', 'contract', 'copi', 'copi', 'corp', 'corp', 'corp', 'count', 'csiko', 'custom', 'custom', 'daren', 'date', 'deal', 'deal', 'deal', 'deal', 'desk', 'direct', 'discuss', 'discuss', 'dscottl', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'ensur', 'entex', 'equistar', 'eric', 'etc', 'expens', 'expens', 'extern', 'farmer', 'follow', 'follow', 'friday', 'friday', 'handl', 'head', 'herod', 'hl', 'hope', 'hou', 'hou', 'hou', 'hou', 'hou', 'howard', 'imbal', 'impact', 'industri', 'invoic', 'item', 'januari', 'job', 'know', 'know', 'let', 'let', 'like', 'lisa', 'list', 'list', 'list', 'list', 'locat', 'lunch', 'mail', 'major', 'may', 'may', 'may', 'meet', 'meet', 'meet', 'meet', 'meet', 'meter', 'meter', 'need', 'new', 'order', 'other', 'overview', 'overview', 'pamela', 'pat', 'pleas', 'pleas', 'pleas', 'pm', 'pm', 'pm', 'prior', 'process', 'question', 'question', 'question', 'quickli', 'realiz', 'repres', 'rhonda', 'rita', 'robinson', 'role', 'set', 'settlement', 'settlement', 'shipper', 'someon', 'someon', 'soon', 'special', 'specif', 'structur', 'subject', 'summari', 'summari', 'swing', 'texa', 'thank', 'thank', 'thing', 'time', 'time', 'topic', 'transact', 'transact', 'transact', 'transport', 'via', 'vm', 'vm', 'vm', 'want', 'would', 'wynn', 'yvett']",
#  "['buyback', 'deal', 'econom', 'forc', 'handl', 'hr', 'inform', 'ken', 'know', 'let', 'long', 'majur', 'morn', 'move', 'plant', 'pleas', 'thank', 'turnaround', 'us', 'week', 'went']",
#  "['also', 'ask', 'background', 'beamont', 'beaumont', 'beaumont', 'beaumont', 'beaumont', 'beaumont', 'beaumont', 'beaumont', 'beaumont', 'beaumont', 'bob', 'brandywin', 'brandywin', 'brandywin', 'busi', 'busi', 'call', 'call', 'call', 'call', 'caus', 'chyral', 'clarifi', 'confus', 'contact', 'contact', 'control', 'control', 'control', 'control', 'control', 'cours', 'dorcheu', 'downstream', 'dupont', 'dupont', 'dupont', 'dupont', 'emerg', 'everybodi', 'fact', 'feed', 'feed', 'first', 'follow', 'ga', 'ga', 'get', 'goe', 'great', 'hankin', 'header', 'hpl', 'issu', 'issu', 'issu', 'issu', 'issu', 'lee', 'loop', 'meter', 'meter', 'meter', 'methanol', 'methanol', 'methanol', 'methanol', 'methanol', 'methanol', 'methanol', 'methanol', 'methanol', 'methanol', 'nomin', 'nomin', 'nomin', 'nomin', 'obvious', 'ok', 'one', 'oper', 'pipelin', 'plant', 'plant', 'plant', 'pleas', 'regard', 'regard', 'room', 'room', 'room', 'schedul', 'schedul', 'schedul', 'schedul', 'shop', 'sometim', 'sometim', 'station', 'station', 'tell', 'terra', 'thank', 'today', 'type', 'weekend', 'yesterday']",
#  "['around', 'ask', 'avoid', 'back', 'bid', 'bob', 'bridg', 'bridg', 'busi', 'clean', 'clean', 'could', 'data', 'edi', 'els', 'end', 'everyon', 'expect', 'help', 'help', 'identifi', 'keep', 'keep', 'keep', 'know', 'let', 'logist', 'maintain', 'make', 'make', 'month', 'month', 'month', 'must', 'non', 'one', 'part', 'perform', 'pipe', 'pipe', 'pleas', 'problem', 'rather', 'reason', 'schedul', 'schedul', 'see', 'speak', 'staff', 'statu', 'sure', 'sure', 'thank', 'thing', 'throughout', 'throughout', 'top', 'unifi', 'wait', 'week', 'work']",
#  "['acton', 'base', 'brian', 'carlo', 'carlo', 'cc', 'compani', 'compani', 'corp', 'donald', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'enron', 'enron', 'follow', 'forward', 'gener', 'grave', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hsc', 'hsc', 'inc', 'less', 'less', 'melissa', 'mmbtu', 'mmbtu', 'petroleum', 'petroleum', 'petroleum', 'phillip', 'phillip', 'phillip', 'pleas', 'pm', 'reinhardt', 'riley', 'rodriguez', 'rodriguez', 'sitara', 'smith', 'spot', 'subject', 'susan', 'taylor', 'thank', 'ticket', 'tom', 'tom', 'upon', 'vanc', 'vlt']",
#  "['acton', 'addit', 'advis', 'alert', 'aris', 'attach', 'call', 'carlo', 'carlo', 'cc', 'collect', 'come', 'corp', 'coupl', 'current', 'deal', 'donald', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'enron', 'enron', 'enter', 'estim', 'estim', 'estim', 'expect', 'februari', 'februari', 'februari', 'file', 'forward', 'give', 'grave', 'highlight', 'hou', 'hou', 'hou', 'hou', 'hou', 'list', 'melissa', 'meter', 'month', 'nom', 'pleas', 'pleas', 'pm', 'pm', 'preliminari', 'process', 'produc', 'produc', 'product', 'product', 'question', 'reinhardt', 'request', 'revis', 'rodriguez', 'rodriguez', 'see', 'servic', 'sitara', 'smith', 'subject', 'susan', 'taylor', 'thank', 'ticket', 'time', 'tom', 'tom', 'trade', 'vanc', 'vlt', 'wellhead', 'zone']",
#  "['abl', 'access', 'access', 'accord', 'addit', 'ago', 'appreci', 'ask', 'avail', 'award', 'award', 'behind', 'broadband', 'build', 'card', 'celebr', 'cent', 'cent', 'certain', 'certif', 'coffe', 'com', 'come', 'commit', 'commun', 'compani', 'compani', 'compani', 'contact', 'continu', 'copi', 'corp', 'day', 'day', 'dec', 'desk', 'detail', 'difficulti', 'document', 'donut', 'drive', 'due', 'earli', 'effect', 'elig', 'employe', 'employe', 'employe', 'encount', 'energi', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'everi', 'exercis', 'exercis', 'experienc', 'feb', 'feb', 'forc', 'form', 'frequent', 'full', 'fulli', 'global', 'grant', 'grant', 'grant', 'grant', 'great', 'happen', 'hard', 'help', 'help', 'high', 'home', 'human', 'includ', 'inform', 'intern', 'intern', 'ip', 'jan', 'januari', 'java', 'ken', 'ken', 'kreme', 'krispi', 'last', 'lay', 'legal', 'list', 'local', 'locat', 'locat', 'long', 'made', 'made', 'make', 'manag', 'mark', 'may', 'mean', 'mean', 'messag', 'messag', 'messag', 'must', 'must', 'next', 'occas', 'offer', 'option', 'option', 'option', 'option', 'option', 'option', 'option', 'option', 'option', 'own', 'part', 'pass', 'payrol', 'pc', 'peopl', 'peopl', 'peopl', 'percent', 'percent', 'percent', 'perform', 'place', 'plan', 'plan', 'plaza', 'pleas', 'price', 'price', 'provis', 'quantiti', 'question', 'receiv', 'receiv', 'receiv', 'recognit', 'regard', 'regular', 'regular', 'repres', 'resourc', 'restrict', 'sent', 'servic', 'seven', 'seven', 'show', 'sound', 'special', 'special', 'special', 'stock', 'stock', 'stock', 'stock', 'stock', 'stock', 'stock', 'street', 'subsequ', 'success', 'success', 'success', 'surpass', 'talk', 'talk', 'technic', 'term', 'term', 'th', 'thank', 'thereaft', 'therefor', 'time', 'time', 'today', 'transcript', 'tv', 'vari', 'vest', 'vest', 'view', 'view', 'visit', 'wall', 'week', 'week', 'wholli', 'work', 'work', 'year', 'year']",
#  "['approxim', 'call', 'current', 'day', 'entex', 'estim', 'estim', 'estim', 'factor', 'gari', 'get', 'pop', 'question', 'revis', 'revis', 'short', 'show', 'spreadsheet', 'today', 'work', 'would']",
#  "['addit', 'assum', 'bob', 'bob', 'brennan', 'brennan', 'btu', 'cc', 'contact', 'day', 'day', 'dri', 'ect', 'ect', 'ect', 'effect', 'energi', 'est', 'estim', 'factor', 'feb', 'februari', 'felip', 'field', 'forward', 'fyi', 'hou', 'hou', 'houston', 'hpl', 'inform', 'josey', 'josey', 'kc', 'kc', 'kc', 'kevin', 'knox', 'mail', 'mail', 'mclarney', 'mmbtu', 'mmbtu', 'month', 'need', 'nomin', 'nomin', 'page', 'pm', 'pm', 'ranch', 'ranch', 'resourc', 'san', 'stretch', 'stretch', 'subject', 'suit', 'susan', 'susan', 'taylor', 'total', 'trevino', 'trevino', 'tx', 'vanc', 'victoria', 'voic', 'volum', 'westmoreland', 'wither', 'wither']",
#  "['address', 'address', 'author', 'box', 'complet', 'contact', 'contact', 'copi', 'copi', 'corp', 'detail', 'duplic', 'duplic', 'eb', 'enron', 'fax', 'februari', 'follow', 'form', 'form', 'form', 'form', 'form', 'ginger', 'ginger', 'group', 'houston', 'includ', 'includ', 'inform', 'inform', 'januari', 'mail', 'mail', 'mail', 'may', 'may', 'may', 'messag', 'name', 'need', 'note', 'number', 'number', 'one', 'payrol', 'phone', 'pleas', 'pleas', 'pleas', 'possibl', 'process', 'question', 'question', 'receipt', 'receiv', 'record', 'regard', 'request', 'request', 'request', 'request', 'request', 'request', 'request', 'requir', 'retire', 'secur', 'sent', 'sign', 'signatur', 'sinclair', 'social', 'someon', 'soon', 'specifi', 'take', 'tax', 'tax', 'th', 'thank', 'tx', 'week', 'within', 'write', 'written', 'year']",
#  "['began', 'chang', 'daren', 'date', 'deal', 'deal', 'decatherm', 'flow', 'indic', 'jacki', 'meter', 'notifi', 'pleas', 'reflect', 'sitara', 'start', 'th', 'thank', 'ticket', 'ticket', 'versu', 'volum', 'whether']",
#  "['ajello', 'andrew', 'cc', 'corp', 'corp', 'corp', 'corp', 'crump', 'custom', 'custom', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'forward', 'gari', 'gari', 'glenn', 'hou', 'hou', 'hou', 'hou', 'hpl', 'industri', 'jame', 'jame', 'jim', 'king', 'lamphier', 'lamphier', 'lee', 'list', 'list', 'mackey', 'papayoti', 'pm', 'pm', 'request', 'subject', 'texa', 'wendi', 'wilson', 'wright']",
#  "['ami', 'ami', 'attach', 'cc', 'chang', 'chokshi', 'chokshi', 'com', 'corp', 'corp', 'edmondson', 'egmnom', 'egmnom', 'enron', 'enron', 'enron', 'feb', 'feb', 'file', 'forward', 'georg', 'hpl', 'nom', 'pass', 'pm', 'pm', 'reliantenergi', 'revis', 'royal', 'see', 'subject', 'xl', 'xl']",
#  "['ami', 'ami', 'ami', 'ami', 'attach', 'attach', 'benoit', 'cc', 'cc', 'chokshi', 'chokshi', 'chokshi', 'chokshi', 'close', 'com', 'com', 'copano', 'corp', 'corp', 'corp', 'corp', 'edmondson', 'egmnom', 'egmnom', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'eye', 'feb', 'feb', 'feb', 'feb', 'feb', 'file', 'file', 'forward', 'forward', 'hpl', 'hpl', 'keep', 'lst', 'nom', 'reliantenergi', 'reliantenergi', 'revis', 'revis', 'royal', 'see', 'see', 'small', 'subject', 'subject', 'troy', 'weather', 'weather', 'xl', 'xl', 'xl', 'xl']",
#  "['ac', 'alloc', 'alloc', 'approach', 'cap', 'charg', 'come', 'daili', 'daili', 'day', 'differ', 'end', 'entex', 'exceed', 'excess', 'far', 'gd', 'get', 'greater', 'howev', 'jan', 'januari', 'look', 'month', 'must', 'need', 'number', 'show', 'tend', 'thank', 'thu', 'toward', 'tran', 'transact', 'volum', 'volum', 'volum', 'volum', 'winter']",
#  "['ami', 'ami', 'attach', 'bowen', 'bryan', 'campo', 'cc', 'ce', 'ce', 'chokshi', 'chokshi', 'conni', 'corp', 'corp', 'corp', 'daigl', 'dana', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'edward', 'elli', 'enron', 'enron', 'enron', 'enron', 'enron', 'fay', 'forward', 'friedman', 'gosnel', 'held', 'hilliard', 'hodg', 'hogan', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'irena', 'januari', 'januari', 'jeffrey', 'katherin', 'kelli', 'lamadrid', 'linda', 'mari', 'mari', 'mark', 'marlen', 'meet', 'meet', 'mill', 'minut', 'minut', 'monday', 'pm', 'pm', 'scott', 'sever', 'solmonson', 'stephani', 'subject', 'sutton', 'sylvia', 'terri', 'tricia', 'victor']",
#  "['anoth', 'attl', 'away', 'bare', 'believ', 'better', 'big', 'bridg', 'build', 'camil', 'camil', 'camil', 'cc', 'cheryl', 'class', 'congrat', 'could', 'daren', 'davi', 'davi', 'die', 'door', 'ed', 'eit', 'envelop', 'ever', 'ever', 'ever', 'exam', 'fenni', 'fricken', 'glover', 'glover', 'glover', 'glover', 'greg', 'head', 'hell', 'hell', 'htm', 'januari', 'kcdavi', 'know', 'know', 'know', 'kubin', 'kyle', 'kyle', 'later', 'let', 'let', 'licens', 'licens', 'like', 'mail', 'mail', 'mail', 'mail', 'mail', 'mail', 'mailto', 'make', 'messag', 'monday', 'morn', 'net', 'never', 'next', 'ngccorp', 'ngccorp', 'open', 'origin', 'pass', 'past', 'pdq', 'pm', 'pm', 'probabl', 'rememb', 'rochel', 'rusti', 'rusti', 'rusti', 'rusti', 'see', 'sent', 'sign', 'stay', 'studi', 'subject', 'subject', 'tell', 'test', 'time', 'took', 'well', 'ye']",
#  "['ami', 'ami', 'attach', 'benoit', 'cc', 'chokshi', 'chokshi', 'com', 'corp', 'corp', 'enron', 'enron', 'enron', 'feb', 'feb', 'file', 'forward', 'hpl', 'hpl', 'increas', 'midcon', 'reliantenergi', 'see', 'subject', 'troy', 'volum', 'xl', 'xl']",
#  "['dec', 'exceed', 'excess', 'feb', 'fom', 'greater', 'hsc', 'jan', 'mar', 'nov', 'price', 'price', 'time', 'volum']",
#  "['account', 'advanc', 'aime', 'aime', 'aime', 'aime', 'anoth', 'arrang', 'bit', 'boa', 'bridgeback', 'bridgeback', 'cc', 'contract', 'creat', 'daren', 'deal', 'deal', 'deal', 'deal', 'deal', 'deal', 'deal', 'determin', 'ect', 'ect', 'ect', 'error', 'error', 'error', 'expir', 'expir', 'extend', 'extend', 'fix', 'flow', 'forward', 'fred', 'fred', 'help', 'hou', 'hou', 'lannou', 'lannou', 'littl', 'meter', 'meter', 'meter', 'month', 'month', 'need', 'new', 'nov', 'number', 'one', 'pleas', 'pm', 'pm', 'put', 'reason', 'referenc', 'replac', 'seem', 'set', 'sinc', 'subject', 'thank', 'transport', 'valid', 'want', 'way']",
#  "['carthag', 'cotton', 'eastran', 'equat', 'fuel', 'hpl', 'interconnect', 'like', 'mcf', 'mmbtu', 'mmbtu', 'mmbtu', 'nomin', 'redeliv', 'tailgat', 'valley']",
#  "['almost', 'around', 'asap', 'borrow', 'busi', 'busi', 'button', 'car', 'caus', 'caus', 'close', 'cole', 'com', 'comp', 'competit', 'could', 'curtain', 'day', 'differ', 'earli', 'email', 'everyon', 'everyth', 'finish', 'free', 'fri', 'front', 'get', 'get', 'get', 'get', 'get', 'give', 'go', 'goe', 'got', 'got', 'got', 'hey', 'hick', 'home', 'home', 'hotmail', 'http', 'hug', 'kind', 'kinda', 'know', 'know', 'laci', 'let', 'love', 'made', 'mail', 'materi', 'mayb', 'mess', 'mon', 'night', 'offic', 'ok', 'order', 'plano', 'post', 'privat', 'probabl', 'routin', 'row', 'sat', 'sat', 'see', 'shane', 'someon', 'sometim', 'sun', 'ta', 'time', 'tonya', 'town', 'us', 'wait', 'want', 'want', 'week', 'wish', 'work', 'www', 'ya']",
#  "['account', 'aime', 'alloc', 'alway', 'arrang', 'bammel', 'creat', 'daren', 'deal', 'deal', 'everi', 'gener', 'get', 'inject', 'know', 'land', 'let', 'manag', 'meter', 'month', 'nomin', 'pleas', 'pop', 'set', 'storag', 'texa', 'thank', 'today', 'use', 'volum', 'want', 'withhold']",
#  "['activ', 'allen', 'alloc', 'alloc', 'also', 'also', 'also', 'anita', 'anita', 'answer', 'believ', 'caus', 'cc', 'cernosek', 'check', 'clem', 'clue', 'clyne', 'continu', 'corp', 'could', 'could', 'daren', 'deal', 'deal', 'dealmak', 'deliveri', 'deliveri', 'deliveri', 'ect', 'ect', 'ect', 'ect', 'ect', 'end', 'enron', 'enron', 'error', 'explain', 'express', 'farmer', 'forget', 'forward', 'georg', 'get', 'give', 'grave', 'hate', 'hou', 'hou', 'hou', 'jacki', 'jacki', 'jacki', 'jill', 'know', 'lauri', 'let', 'life', 'may', 'melissa', 'mention', 'meter', 'meter', 'meter', 'meter', 'might', 'nom', 'nom', 'nom', 'part', 'pat', 'pleas', 'pm', 'pm', 'probabl', 'product', 'purchas', 'purpos', 'question', 'receipt', 'receipt', 'rememb', 'repres', 'sale', 'see', 'sinc', 'situat', 'spectrum', 'subject', 'support', 'tesoro', 'thing', 'valid', 'volum', 'weissman', 'young', 'young', 'zive']",
#  "['activ', 'allen', 'allen', 'alloc', 'alloc', 'also', 'also', 'also', 'amount', 'anita', 'anita', 'anita', 'answer', 'believ', 'buy', 'caus', 'cc', 'cc', 'cernosek', 'cernosek', 'check', 'clem', 'clem', 'clue', 'clyne', 'clyne', 'continu', 'corp', 'corp', 'could', 'could', 'daren', 'daren', 'deal', 'deal', 'dealmak', 'deliveri', 'deliveri', 'deliveri', 'deliveri', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'ect', 'end', 'enron', 'enron', 'enron', 'enron', 'error', 'everi', 'explain', 'express', 'farmer', 'farmer', 'fix', 'forget', 'forward', 'fuel', 'georg', 'get', 'give', 'grave', 'hate', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'hou', 'howev', 'hplc', 'hplr', 'jacki', 'jacki', 'jacki', 'jacki', 'jill', 'kept', 'know', 'lauri', 'lauri', 'let', 'life', 'luong', 'may', 'melissa', 'mention', 'meter', 'meter', 'meter', 'meter', 'meter', 'meter', 'meter', 'meter', 'might', 'month', 'nom', 'nom', 'nom', 'nom', 'part', 'pat', 'pat', 'pleas', 'pm', 'pm', 'pm', 'probabl', 'product', 'purchas', 'purpos', 'question', 'receipt', 'receipt', 'receipt', 'rememb', 'repres', 'sale', 'see', 'sell', 'sinc', 'situat', 'spectrum', 'subject', 'subject', 'support', 'tesoro', 'thing', 'valid', 'volum', 'volum', 'weissman', 'whole', 'young', 'young', 'young', 'zive']",
#  "['access', 'begin', 'cole', 'com', 'daren', 'date', 'dl', 'end', 'feb', 'forward', 'forward', 'free', 'free', 'fri', 'get', 'hous', 'http', 'hunter', 'hunter', 'id', 'internet', 'internet', 'jill', 'jill', 'juno', 'juno', 'let', 'look', 'love', 'messag', 'messag', 'messag', 'much', 'new', 'offer', 'pay', 'pictur', 'pictur', 'pictur', 'pictur', 'pictur', 'ram', 'ram', 'risk', 'softwar', 'subject', 'susan', 'tackett', 'tagj', 'today', 'tonya', 'tri', 'visit', 'weekend', 'www']",
#  "['accept', 'access', 'access', 'account', 'addit', 'allow', 'appreci', 'attach', 'attach', 'attach', 'attach', 'attach', 'awar', 'begin', 'best', 'call', 'capabl', 'capac', 'carri', 'caus', 'cd', 'central', 'com', 'com', 'com', 'comput', 'comput', 'connect', 'continu', 'current', 'daren', 'date', 'dear', 'dl', 'download', 'download', 'download', 'download', 'download', 'encourag', 'end', 'enhanc', 'file', 'fill', 'find', 'first', 'forward', 'forward', 'free', 'free', 'get', 'guess', 'handl', 'help', 'howev', 'http', 'http', 'id', 'inc', 'incom', 'instal', 'internet', 'internet', 'juno', 'juno', 'juno', 'juno', 'juno', 'juno', 'juno', 'juno', 'juno', 'juno', 'juno', 'juno', 'kept', 'latest', 'latest', 'limit', 'love', 'mail', 'mail', 'mail', 'mail', 'mail', 'mail', 'mailbox', 'mailbox', 'mani', 'maximum', 'maximum', 'may', 'may', 'member', 'messag', 'messag', 'messag', 'messag', 'messag', 'messag', 'messag', 'messag', 'messag', 'miss', 'much', 'need', 'need', 'new', 'new', 'new', 'new', 'offer', 'onlin', 'order', 'order', 'particularli', 'pay', 'pleas', 'prevent', 'problem', 'reach', 'receiv', 'receiv', 'receiv', 'receiv', 'regard', 'retriev', 'retriev', 'risk', 'rom', 'send', 'server', 'servic', 'servic', 'size', 'softwar', 'softwar', 'softwar', 'softwar', 'softwar', 'still', 'subject', 'support', 'support', 'support', 'tagj', 'tech', 'technic', 'thank', 'today', 'tri', 'tri', 'unabl', 'unabl', 'upgrad', 'upgrad', 'upgrad', 'us', 'use', 'use', 'use', 'version', 'version', 'version', 'version', 'version', 'visit', 'visit', 'wait', 'web', 'web', 'wide', 'world', 'www', 'www', 'yet']",
#  "['afternoon', 'afternoon', 'best', 'best', 'call', 'call', 'com', 'com', 'confer', 'daren', 'daren', 'daren', 'dfarmer', 'earlier', 'ect', 'enron', 'farmer', 'februari', 'friday', 'friday', 'hour', 'know', 'let', 'let', 'like', 'locat', 'mailto', 'mam', 'messag', 'michael', 'mike', 'mike', 'mike', 'open', 'origin', 'plan', 'pm', 'pm', 'pm', 'room', 'schedul', 'sent', 'subject', 'teamlead', 'th', 'thursday', 'thursday', 'usual', 'work']",
#  "['air', 'ami', 'ami', 'attach', 'benoit', 'cc', 'chang', 'chokshi', 'chokshi', 'com', 'corp', 'corp', 'duke', 'egmnom', 'egmnom', 'enron', 'enron', 'enron', 'feb', 'feb', 'file', 'forward', 'liquid', 'reliantenergi', 'see', 'subject', 'th', 'troy', 'xl', 'xl']",
# ...
#  "['abl', 'access', 'accur', 'affect', 'ago', 'also', 'analysi', 'anoth', 'approach', 'appropri', 'associ', 'avail', 'base', 'base', 'base', 'bitran', 'brought', 'busi', 'buy', 'buy', 'call', 'came', 'came', 'captur', 'case', 'cc', 'certain', 'charg', 'choic', 'choic', 'choic', 'choic', 'choic', 'choic', 'choic', 'choic', 'choic', 'choic', 'combin', 'come', 'common', 'common', 'compani', 'compani', 'compani', 'compani', 'compani', 'compani', 'compani', 'compon', 'compon', 'compon', 'compon', 'comput', 'consist', 'consist', 'consum', 'consum', 'consum', 'consum', 'consum', 'context', 'cours', 'coursework', 'currect', 'custom', 'custom', 'custom', 'custom', 'custom', 'custom', 'custom', 'deal', 'decid', 'decid', 'describ', 'develop', 'develop', 'develop', 'differ', 'differ', 'divid', 'draw', 'easili', 'econom', 'econom', 'economist', 'ect', 'elimin', 'elimin', 'elimin', 'etc', 'exactli', 'exist', 'face', 'fact', 'featur', 'first', 'first', 'flexibl', 'focu', 'forward', 'forward', 'furthermor', 'gabriel', 'gener', 'gener', 'gibner', 'gibner', 'give', 'given', 'go', 'good', 'graduat', 'great', 'gro', 'gro', 'group', 'harvard', 'help', 'henc', 'heurist', 'horizon', 'hou', 'houston', 'idea', 'import', 'includ', 'inevit', 'influenc', 'inform', 'inform', 'innov', 'interact', 'interact', 'interest', 'interest', 'interest', 'internet', 'internet', 'internet', 'internet', 'internet', 'internet', 'internet', 'internet', 'internet', 'internet', 'internet', 'invit', 'issu', 'know', 'know', 'learn', 'learn', 'lend', 'literatur', 'logit', 'long', 'long', 'look', 'mail', 'main', 'make', 'make', 'make', 'manag', 'manag', 'manag', 'mani', 'mani', 'mathemat', 'mathemat', 'mathemat', 'mathemat', 'mathemat', 'maxim', 'maxim', 'maxim', 'meet', 'method', 'method', 'method', 'methodolog', 'mit', 'mit', 'model', 'model', 'model', 'model', 'model', 'model', 'model', 'model', 'model', 'model', 'model', 'model', 'model', 'model', 'model', 'motiv', 'motiv', 'much', 'much', 'must', 'need', 'new', 'next', 'next', 'number', 'number', 'number', 'object', 'offer', 'offer', 'oliveira', 'one', 'one', 'oper', 'oper', 'optim', 'optim', 'optim', 'optim', 'optim', 'optim', 'optim', 'option', 'overload', 'particular', 'paulo', 'paulo', 'phd', 'phd', 'phone', 'plan', 'pm', 'pm', 'polici', 'price', 'price', 'price', 'price', 'price', 'price', 'price', 'price', 'price', 'princeton', 'problem', 'problem', 'problem', 'problem', 'problem', 'problem', 'problem', 'process', 'product', 'product', 'product', 'product', 'product', 'product', 'prof', 'profit', 'profit', 'psycholog', 'psycholog', 'psycholog', 'psycholog', 'psycholog', 'reflect', 'relat', 'remain', 'requir', 'reseach', 'research', 'research', 'research', 'research', 'research', 'research', 'resum', 'retain', 'revenu', 'revenu', 'rocha', 'sale', 'sale', 'say', 'schoolof', 'search', 'send', 'sent', 'sequenti', 'servic', 'servic', 'servic', 'servic', 'servic', 'servic', 'servic', 'set', 'short', 'short', 'show', 'significantli', 'sloan', 'sold', 'sourc', 'specif', 'step', 'still', 'stinson', 'stinson', 'stinson', 'stinson', 'stochast', 'straight', 'strateg', 'strategi', 'strategi', 'strategi', 'student', 'subject', 'substitut', 'substitut', 'substitut', 'substitut', 'summari', 'technolog', 'tend', 'tent', 'term', 'term', 'term', 'term', 'thank', 'thank', 'therefor', 'thesi', 'three', 'titl', 'tom', 'tom', 'took', 'tool', 'tractabl', 'tradit', 'tradit', 'transferr', 'trip', 'two', 'two', 'type', 'type', 'uniqu', 'uniqu', 'univers', 'use', 'usual', 'util', 'vcr', 'way', 'wednesday', 'week', 'week', 'well', 'well', 'without', 'work', 'would', 'year']",
#  "['alex', 'arnold', 'attach', 'butler', 'copi', 'copi', 'enjoy', 'good', 'gopop', 'hey', 'hope', 'lsu', 'mail', 'paper', 'paper', 'pdf', 'schwartz', 'see', 'sent', 'sincer', 'tom', 'understand', 'vinc', 'visit']",
#  "['absolut', 'ad', 'ago', 'book', 'box', 'call', 'cc', 'chat', 'commod', 'day', 'day', 'ect', 'ect', 'ect', 'ect', 'ed', 'ed', 'email', 'email', 'email', 'email', 'energi', 'enron', 'eol', 'find', 'free', 'friend', 'give', 'good', 'hou', 'houston', 'kaminski', 'kaminski', 'kitchen', 'know', 'krapel', 'krapel', 'learn', 'like', 'lon', 'london', 'lost', 'lost', 'lot', 'louis', 'louis', 'louis', 'market', 'may', 'messag', 'minut', 'move', 'number', 'password', 'phone', 'previou', 'regard', 'sent', 'sort', 'subject', 'time', 'us', 'vinc', 'vinc', 'vinc', 'would', 'would', 'write']",
#  "['addit', 'affair', 'affair', 'affair', 'affair', 'affair', 'affair', 'affair', 'affair', 'affair', 'affair', 'africa', 'agenc', 'america', 'america', 'america', 'american', 'announc', 'apachi', 'apachi', 'around', 'asia', 'assum', 'assum', 'assum', 'attach', 'attach', 'attent', 'becom', 'bestard', 'busi', 'busi', 'canada', 'caribbean', 'chang', 'chang', 'chart', 'charvel', 'chief', 'cone', 'congratul', 'continu', 'current', 'current', 'current', 'current', 'current', 'directli', 'director', 'director', 'enron', 'enron', 'enron', 'enron', 'enron', 'environ', 'environ', 'environment', 'environment', 'environment', 'europ', 'europ', 'face', 'feder', 'financ', 'financ', 'focu', 'follow', 'ga', 'global', 'govern', 'govern', 'govern', 'govern', 'govern', 'govern', 'govern', 'govern', 'govern', 'group', 'hardi', 'health', 'health', 'hill', 'increasingli', 'india', 'india', 'individu', 'involv', 'issu', 'jane', 'joe', 'john', 'john', 'join', 'jose', 'lead', 'lead', 'leadership', 'manag', 'mark', 'mark', 'mark', 'mexico', 'mike', 'mike', 'mike', 'mike', 'multilater', 'north', 'north', 'offic', 'organ', 'organ', 'organ', 'pipelin', 'pleas', 'pleas', 'presid', 'presid', 'presid', 'presid', 'presid', 'presid', 'project', 'project', 'reflect', 'region', 'region', 'regulatori', 'regulatori', 'regulatori', 'regulatori', 'report', 'report', 'report', 'repres', 'respons', 'respons', 'respons', 'respons', 'respons', 'retain', 'revis', 'ricardo', 'rick', 'rick', 'rick', 'rick', 'safeti', 'safeti', 'schroeder', 'senior', 'serv', 'serv', 'shapiro', 'south', 'south', 'southern', 'support', 'support', 'team', 'team', 'team', 'team', 'team', 'terraso', 'unit', 'us', 'us', 'vice', 'vice', 'vice', 'vice', 'vice', 'vice', 'well', 'wilson', 'world']",
#  "['accomod', 'activ', 'associ', 'august', 'august', 'busi', 'charlen', 'charli', 'date', 'discuss', 'earlier', 'earmark', 'expect', 'group', 'handshak', 'hurrican', 'incom', 'june', 'june', 'link', 'mike', 'offici', 'organ', 'orient', 'particip', 'project', 'purpos', 'regularli', 'relat', 'releas', 'report', 'request', 'request', 'research', 'robert', 'rotat', 'schedul', 'season', 'st', 'start', 'start', 'start', 'th', 'thank', 'thank', 'wednesday', 'weldon']",
#  "['add', 'agre', 'answer', 'berlin', 'confer', 'could', 'day', 'dear', 'delight', 'helyett', 'icbi', 'june', 'kind', 'major', 'may', 'one', 'option', 'real', 'regard', 'share', 'similar', 'topic', 'tuesday', 'vinc', 'workshop', 'would', 'would']",
#  "['anyth', 'basic', 'chonawe', 'chonawe', 'co', 'day', 'depart', 'eb', 'els', 'follow', 'great', 'group', 'head', 'hello', 'inform', 'kaminski', 'know', 'let', 'locat', 'manag', 'manag', 'name', 'need', 'need', 'new', 'order', 'order', 'packag', 'phone', 'pleas', 'pleas', 'rc', 'research', 'research', 'shirley', 'studio', 'supatgiat', 'supatgiat', 'thank', 'titl', 'vinc', 'visual', 'visual']",
#  "['access', 'allow', 'case', 'contact', 'difficulti', 'enrononlin', 'enrononlin', 'eol', 'follow', 'guest', 'help', 'helpdesk', 'id', 'id', 'id', 'intern', 'log', 'note', 'password', 'password', 'password', 'pleas', 'pleas', 'question', 'sensit', 'user', 'user', 'view', 'vinc', 'welcom']",
#  "['add', 'agre', 'answer', 'aol', 'berlin', 'cc', 'com', 'com', 'confer', 'could', 'day', 'dear', 'delight', 'enron', 'gemanix', 'glad', 'helyett', 'helyett', 'icbi', 'join', 'june', 'kind', 'major', 'may', 'one', 'option', 'real', 'regard', 'shall', 'share', 'similar', 'subject', 'topic', 'tuesday', 'vinc', 'vinc', 'vkamin', 'workshop', 'workshop', 'would', 'would']",
#  "['accordingli', 'anjam', 'ben', 'best', 'book', 'close', 'corner', 'develop', 'dinner', 'discuss', 'diverso', 'earli', 'even', 'free', 'hd', 'hi', 'hotel', 'hotel', 'hyde', 'know', 'lane', 'lane', 'lane', 'latest', 'left', 'let', 'like', 'like', 'london', 'make', 'make', 'number', 'one', 'opportun', 'park', 'park', 'park', 'park', 'piccadilli', 'plan', 'pleas', 'regard', 'restaur', 'schedul', 'seem', 'slot', 'stay', 'steve', 'sunday', 'sure', 'tabl', 'tel', 'telephon', 'underground', 'vinc', 'vinc', 'vinc', 'wlv', 'would', 'yard']",
#  "['credit', 'credit', 'credit', 'deal', 'factor', 'file', 'issler', 'model', 'paulo', 'pm', 'price', 'risk', 'risk', 'risk', 'talk', 'thank', 'tomorrow', 'two', 'vinc', 'without', 'without']",
#  "['aa', 'back', 'chanc', 'chang', 'comment', 'consid', 'consid', 'copi', 'courier', 'custom', 'custom', 'deriv', 'draft', 'eb', 'either', 'email', 'enclos', 'exampl', 'exampl', 'fax', 'four', 'hedg', 'insur', 'issu', 'john', 'make', 'martin', 'meet', 'need', 'noon', 'outlin', 'partner', 'pleas', 'pleas', 'possibl', 'product', 'rather', 'receiv', 'recommend', 'recommend', 'request', 'review', 'review', 'send', 'send', 'send', 'show', 'signific', 'suggest', 'suggest', 'thursday', 'trade', 'trade', 'treatment', 'via', 'word', 'would', 'write']",
#  "['analyst', 'attend', 'bright', 'cc', 'consid', 'cover', 'cover', 'doc', 'dr', 'ect', 'enron', 'enron', 'forward', 'forward', 'gave', 'hou', 'ile', 'ile', 'ile', 'kaminski', 'kaminski', 'lectur', 'letter', 'lsu', 'lynn', 'man', 'motiv', 'opportun', 'pleas', 'posit', 'recent', 'respond', 'resum', 'resum', 'resum', 'richard', 'richard', 'richard', 'subject', 'thank', 'think', 'vinc', 'vinc', 'young']",
#  "['afternoon', 'avail', 'ben', 'guy', 'interview', 'monday', 'regard', 'three']",
#  "['calendar', 'cl', 'eb', 'fasbl', 'give', 'grumula', 'hello', 'march', 'mark', 'paig', 'pleas', 'pm', 'session', 'shirley', 'thank', 'train', 'tuesday']",
#  "['agri', 'agricultur', 'anyon', 'appreci', 'april', 'area', 'arrang', 'ask', 'assist', 'avail', 'beth', 'beth', 'beth', 'bill', 'carson', 'carson', 'carson', 'cc', 'cc', 'ceo', 'ceo', 'cord', 'corp', 'corp', 'corpor', 'cost', 'could', 'could', 'could', 'custom', 'deroin', 'economist', 'ect', 'ect', 'either', 'electr', 'ena', 'energi', 'energi', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'enron', 'et', 'et', 'et', 'everyth', 'except', 'feel', 'first', 'fluctuat', 'forward', 'ga', 'governor', 'governor', 'governor', 'group', 'hello', 'help', 'help', 'hou', 'impact', 'impact', 'jensen', 'jensen', 'jensen', 'johann', 'johann', 'johann', 'kaminski', 'keep', 'know', 'larri', 'look', 'look', 'look', 'make', 'make', 'manag', 'margaret', 'margaret', 'margaret', 'margaret', 'margaret', 'margaret', 'margaret', 'mark', 'mcgowan', 'meet', 'meet', 'meet', 'mike', 'nation', 'natur', 'nebraska', 'nebraska', 'npng', 'npng', 'oblig', 'offset', 'oil', 'omaha', 'outsid', 'perspect', 'pm', 'pm', 'pm', 'post', 'potenti', 'present', 'present', 'pressur', 'price', 'price', 'product', 'provid', 'qualifi', 'respondt', 'risk', 'rob', 'shall', 'slice', 'speaker', 'speaker', 'speaker', 'specialist', 'subject', 'subject', 'talk', 'thank', 'thank', 'think', 'tool', 'topic', 'topic', 'travel', 'trend', 'type', 'use', 'vinc', 'vinc', 'vinc', 'week', 'well', 'wilson', 'within', 'work', 'would', 'would', 'would']",
#  "['accept', 'access', 'access', 'accommod', 'account', 'activ', 'activ', 'activ', 'ad', 'addit', 'address', 'address', 'address', 'address', 'address', 'adequaci', 'administr', 'administr', 'administr', 'administr', 'advanc', 'advanc', 'advanc', 'advanc', 'advanc', 'advisori', 'advisori', 'advisori', 'advocaci', 'affair', 'affect', 'agenc', 'agenc', 'agenc', 'agenc', 'agenc', 'agreement', 'allow', 'allow', 'also', 'also', 'also', 'america', 'america', 'america', 'american', 'american', 'american', 'analysi', 'analysi', 'analyst', 'ancillari', 'and', 'anderson', 'anderson', 'anderson', 'anderson', 'anderson', 'anderson', 'annual', 'applic', 'approach', 'appropri', 'area', 'area', 'around', 'asia', 'aspect', 'associ', 'assum', 'audienc', 'australian', 'avail', 'background', 'base', 'basi', 'basic', 'basic', 'basic', 'basic', 'bear', 'begin', 'behalf', 'best', 'best', 'bill', 'bill', 'biographi', 'black', 'border', 'break', 'break', 'bring', 'broad', 'bs', 'built', 'busi', 'busi', 'busi', 'busi', 'busi', 'busi', 'busi', 'busi', 'busi', 'busi', 'busi', 'busi', 'calhoun', 'campu', 'canada', 'canada', 'cap', 'card', 'case', 'case', 'caspian', 'caucasu', 'cba', 'cba', 'cba', 'center', 'center', 'center', 'center', 'center', 'certif', 'certifi', 'ceu', 'chair', 'chair', 'challeng', 'chang', 'chang', 'chang', 'china', 'collabor', 'colleagu', 'colleg', 'colleg', 'colleg', 'combin', 'comment', 'commerci', 'commerci', 'commerci', 'commerci', 'commerci', 'commerci', 'commiss', 'commiss', 'committe', 'committe', 'committe', 'committe', 'committe', 'committe', 'committe', 'committe', 'committe', 'commod', 'compani', 'compani', 'competit', 'complet', 'compon', 'comprehens', 'conduct', 'conduct', 'confer', 'confer', 'confidenti', 'congest', 'congest', 'congest', 'congest', 'congest', 'congest', 'consequ', 'constantli', 'construct', 'consult', 'consult', 'consult', 'contact', 'contact', 'contact', 'contact', 'contain', 'content', 'continent', 'control', 'conven', 'converg', 'coordin', 'copi', 'cost', 'council', 'council', 'council', 'countri', 'cours', 'cours', 'cours', 'creation', 'credit', 'credit', 'critic', 'cross', 'current', 'current', 'current', 'custom', 'daili', 'day', 'day', 'day', 'dear', 'decis', 'decis', 'degre', 'demand', 'depth', 'desert', 'design', 'design', 'design', 'desir', 'detail', 'detail', 'develop', 'develop', 'develop', 'develop', 'develop', 'develop', 'develop', 'develop', 'develop', 'develop', 'develop', 'develop', 'develop', 'develop', 'develop', 'differ', 'director', 'director', 'disclos', 'disclosur', 'discuss', 'divid', 'dotti', 'dotti', 'dr', 'dr', 'dr', 'dr', 'dr', 'dr', 'drawn', 'east', 'econom', 'edu', 'edu', 'edu', 'edu', 'edu', 'educ', 'effort', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'electr', 'element', 'email', 'email', 'embed', 'emerg', 'emerg', 'emeri', 'emphasi', 'encourag', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energi', 'energyinstitut', 'energyinstitut', 'energyinstitut', 'energyinstitut', 'engag', 'engin', 'enterpris', 'enterpris', 'entiti', 'environment', 'era', 'ercot', 'ercot', 'ercot', 'ercot', 'ercot', 'ercot', 'ercot', 'ercot', 'ercot', 'ercot', 'ercot', 'ercot', 'ercot', 'especi', 'europ', 'europ', 'execut', 'execut', 'exercis', 'exercis', 'exist', 'exist', 'experi', 'experi', 'experi', 'experi', 'experienc', 'experiment', 'extens', 'extens', 'extens', 'facil', 'facilit', 'faculti', 'fax', 'fax', 'featur', 'februari', 'februari', 'feder', 'feder', 'feder', 'fee', 'ferc', 'ferc', 'field', 'firm', 'firm', 'first', 'focu', 'follow', 'forc', 'foreign', 'form', 'form', 'forward', 'foss', 'foss', 'foss', 'foss', 'foss', 'foss', 'framework', 'framework', 'framework', 'frequent', 'frequent', 'fuel', 'full', 'function', 'function',  ...
#  "['ahmad', 'anjam', 'ben', 'interview', 'kaminski', 'leppard', 'parson', 'schedul', 'stephen', 'vinc']",
#  ...]

# %%
"""WE NEED TO MAKE IT A LIST OF LISTS"""
import ast
data['token']=data['token'].apply(ast.literal_eval)

# %%
def listing(l):
    return l

# %%
tfidf=TfidfVectorizer(analyzer='word',tokenizer=listing,preprocessor=listing,token_pattern=None)

tfidf_matrix=tfidf.fit_transform(data['token'])

# %%
print(type(tfidf_matrix))
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
vectorised_data=pd.DataFrame({"label":data['label'],"vector_space":list(tfidf_matrix)})

# %%
vectorised_data
# Out:
#        label                                       vector_space
# 0          0  <Compressed Sparse Row sparse matrix of dtype ...
# 1          0  <Compressed Sparse Row sparse matrix of dtype ...
# 2          0  <Compressed Sparse Row sparse matrix of dtype ...
# 3          0  <Compressed Sparse Row sparse matrix of dtype ...
# 4          0  <Compressed Sparse Row sparse matrix of dtype ...
# ...      ...                                                ...
# 17832      1  <Compressed Sparse Row sparse matrix of dtype ...
# 17833      1  <Compressed Sparse Row sparse matrix of dtype ...
# 17834      1  <Compressed Sparse Row sparse matrix of dtype ...
# 17835      1  <Compressed Sparse Row sparse matrix of dtype ...
# 17836      1  <Compressed Sparse Row sparse matrix of dtype ...
#
# [17837 rows x 2 columns]

# %%
print(type(vectorised_data.iloc[0]['vector_space']))
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
vectorised_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17837 entries, 0 to 17836
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   label         17837 non-null  int64
#  1   vector_space  17837 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 278.8+ KB

# %%
"""CREATING A NEW DATA SET BUT IN ORDER TO DO SOO WE HAVE TO FIRST STORE THE DATA IN """
import joblib

# joblib.dump(vectorised_data,r"C:\Users\balih\Desktop\AI ML lab work\Python_PBL\Datasets\VECTORIZED_PBL_DATA.pkl")

# %%
"""CALLING THE DATA SET """
data=joblib.load(r"C:\Users\balih\Desktop\AI ML lab work\Python_PBL\Datasets\VECTORIZED_PBL_DATA.pkl")

# %%
data
# Out:
#        label                                       vector_space
# 0          0  <Compressed Sparse Row sparse matrix of dtype ...
# 1          0  <Compressed Sparse Row sparse matrix of dtype ...
# 2          0  <Compressed Sparse Row sparse matrix of dtype ...
# 3          0  <Compressed Sparse Row sparse matrix of dtype ...
# 4          0  <Compressed Sparse Row sparse matrix of dtype ...
# ...      ...                                                ...
# 17832      1  <Compressed Sparse Row sparse matrix of dtype ...
# 17833      1  <Compressed Sparse Row sparse matrix of dtype ...
# 17834      1  <Compressed Sparse Row sparse matrix of dtype ...
# 17835      1  <Compressed Sparse Row sparse matrix of dtype ...
# 17836      1  <Compressed Sparse Row sparse matrix of dtype ...
#
# [17837 rows x 2 columns]

# %%
print(type(data.iloc[0]['vector_space']))
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,precision_score,f1_score,recall_score,confusion_matrix
from sklearn.model_selection import train_test_split

# %%
x=data['vector_space']
y=data['label']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from scipy import sparse

x_trained_sparse_data=sparse.vstack(x_train.tolist())
x_test_sparse_data=sparse.vstack(x_test.tolist())



svm_linear=SVC(kernel='linear')
svm_linear.fit(x_trained_sparse_data,y_train)

y_pred_linear=svm_linear.predict(x_test_sparse_data)

# %%
cm_linear = confusion_matrix(y_test, y_pred_linear)
recall_linear=recall_score(y_test,y_pred_linear,average='weighted')
accuracy_linear=accuracy_score(y_test,y_pred_linear)
f1_linear=f1_score(y_test,y_pred_linear)

# %%
print("FOR LINEAR\n")
print(f"confusion matrix:\n",cm_linear)
print("recall score is:",recall_linear)
print("accuracy_score is:",accuracy_linear)
print("f1 score is :",f1_linear)
# Out:
# FOR LINEAR
#
# confusion matrix:
#  [[1734   96]
#  [  70 1668]]
# recall score is: 0.95347533632287
# accuracy_score is: 0.95347533632287
# f1 score is : 0.952598515134209

# %%
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 919929 stored elements and shape (14269, 80175)>
#   Coords	Values
#   (0, 730)	0.25381458182216193
#   (0, 4408)	0.1547747148256775
#   (0, 6766)	0.2966612608532573
#   (0, 13240)	0.2791703951760017
#   (0, 15909)	0.16887957860140881
#   (0, 21416)	0.2611081597869837
#   (0, 27946)	0.1328741493005039
#   (0, 30582)	0.16151567347061802
#   (0, 35784)	0.257830296252643
#   (0, 37415)	0.12292417560522705
#   (0, 39215)	0.1400628941629994
#   (0, 39616)	0.12283203363517153
#   (0, 40589)	0.19639410323916265
#   (0, 50858)	0.28339705272892185
#   (0, 56861)	0.2941476693634443
#   (0, 56915)	0.14316835411184808
#   (0, 69072)	0.1104719527430111
#   (0, 70380)	0.34581392922538073
#   (0, 75200)	0.2574810005581255
#   (0, 76041)	0.22472008662121226
#   (0, 77378)	0.12022765190231734
#   (1, 255)	0.20524172932798496
#   (1, 747)	0.10111743728108182
#   (1, 1813)	0.18617328777079958
#   (1, 3714)	0.1344168724989766
#   :	:
#   (14268, 46748)	0.04090523040315181
#   (14268, 48117)	0.04377246509110959
#   (14268, 49477)	0.07748239412858882
#   (14268, 50387)	0.11498375164965212
#   (14268, 50631)	0.20085647304375462
#   (14268, 56933)	0.0745367549733248
#   (14268, 57894)	0.11270869879779935
#   (14268, 57910)	0.1440568302591543
#   (14268, 58530)	0.08230584153674196
#   (14268, 58706)	0.1677149293613728
#   (14268, 58927)	0.06104294713302089
#   (14268, 60965)	0.24010321124823936
#   (14268, 65141)	0.07358395934373396
#   (14268, 66900)	0.06671201251500032
#   (14268, 67583)	0.08586991544097744
#   (14268, 68446)	0.12167427791947259
#   (14268, 69072)	0.07584694119724361
#   (14268, 69362)	0.051315569318356145
#   (14268, 69719)	0.04066061322798158
#   (14268, 73164)	0.13573866624381645
#   (14268, 74168)	0.08094491146416169
#   (14268, 75551)	0.04562047827905918
#   (14268, 76032)	0.05033300626133239
#   (14268, 76041)	0.15428650234370797
#   (14268, 76722)	0.10755076595620877
